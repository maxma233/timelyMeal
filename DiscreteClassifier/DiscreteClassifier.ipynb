# %%
import pandas as pd
import numpy as np
from collections import Counter as ctr

# %%
data = pd.read_csv('timelymealsdiscreteannotated.csv', skiprows=1, names=['type','text', 'c3', 'c4', 'c5'], delimiter=',', encoding='ISO-8859-1')

# %%
data['clean'] = data.text.apply(lambda x: x.lower().split())

# %%
data.drop(['c3', 'c4', 'c5'], axis=1, inplace=True)

# %%
data
# Out:
#         type                                               text  \
# 0      Valid                 Generate me a meal plan for 3 days
# 1      Valid  Give me a meal plan for a week and 2 meals per...
# 2      Valid                            Meal plan for the week
# 3      Valid                    Give me a meal plan for the day
# 4      Valid            Generate me a meal plan for the weekend
# ..       ...                                                ...
# 203  Invalid                       Help me eat more vegetables.
# 204  Invalid                  What meals freeze well for later?
# 205  Invalid        Suggest food that helps with energy levels.
# 206  Invalid                     Recommend comfort food dishes.
# 207  Invalid     What can I make for a romantic dinner at home?
#
#                                                  clean
# 0          [generate, me, a, meal, plan, for, 3, days]
# 1    [give, me, a, meal, plan, for, a, week, and, 2...
# 2                         [meal, plan, for, the, week]
# 3             [give, me, a, meal, plan, for, the, day]
# 4     [generate, me, a, meal, plan, for, the, weekend]
# ..                                                 ...
# 203                 [help, me, eat, more, vegetables.]
# 204           [what, meals, freeze, well, for, later?]
# 205  [suggest, food, that, helps, with, energy, lev...
# 206                [recommend, comfort, food, dishes.]
# 207  [what, can, i, make, for, a, romantic, dinner,...
#
# [208 rows x 3 columns]

# %%
data.groupby('type').count()
# Out:
#          text  clean
# type
# Invalid    59     59
# Valid     149    149

# %%
type_ctr = ctr(data.type)

type_ctr['Invalid']/len(data), type_ctr['Valid']/len(data)
# Out:
# (0.28365384615384615, 0.7163461538461539)

# %%
test = data.sample(frac=0.1)
train = data[~data.index.isin(test.index)]

train.shape, test.shape
# Out:
# ((187, 3), (21, 3))

# %% [markdown]
# ### Prior probability

# %%
counter = ctr(train.type)

def Pa(X=''):
    return counter[X] / len(train)

# %%
Pa('Valid')
# Out:
# 0.732620320855615

# %% [markdown]
# ### Normalization

# %%
words_ctr = ctr([word for row in train.clean for word in row])

def Pb(W=''):
    if W not in words_ctr: return 0.000001
    return words_ctr[W] / sum(words_ctr.values())


words_ctr
# Out:
# Counter({'for': 152,
#          'a': 147,
#          'plan': 126,
#          'meal': 114,
#          'the': 79,
#          'next': 57,
#          'meals': 49,
#          'days': 31,
#          'me': 28,
#          'with': 24,
#          'week': 23,
#          'days,': 19,
#          'create': 17,
#          'generate': 16,
#          'suggest': 15,
#          'i': 15,
#          'give': 13,
#          'and': 13,
#          'five': 13,
#          'seven': 12,
#          'including': 12,
#          'on': 12,
#          'weekend': 11,
#          'three': 11,
#          'what': 11,
#          'four': 10,
#          '7': 9,
#          'focusing': 9,
#          'schedule': 8,
#          'dinners': 8,
#          'how': 8,
#          'day': 7,
#          'one': 7,
#          'week,': 7,
#          'six': 7,
#          'make': 7,
#          'can': 7,
#          'healthy': 6,
#          'design': 6,
#          'family': 6,
#          'provide': 6,
#          'to': 6,
#          'all': 6,
#          'breakfasts': 6,
#          '3': 5,
#          'balanced': 5,
#          'monday': 5,
#          'dinner': 5,
#          'snacks': 5,
#          'help': 5,
#          'organize': 5,
#          'show': 5,
#          'build': 5,
#          'lunches': 5,
#          'is': 5,
#          'do': 5,
#          'food': 5,
#          'upcoming': 4,
#          'daily': 4,
#          'friday': 4,
#          'of': 4,
#          'breakfast': 4,
#          'outline': 4,
#          'my': 4,
#          'need': 4,
#          'you': 4,
#          'options': 4,
#          'set': 4,
#          'up': 4,
#          'in': 4,
#          'are': 4,
#          'recommend': 4,
#          'eat': 4,
#          '2': 3,
#          'per': 3,
#          'through': 3,
#          'simple': 3,
#          'out': 3,
#          'ideas': 3,
#          'someone': 3,
#          'busy': 3,
#          'weekly': 3,
#          'variety': 3,
#          'weekdays': 3,
#          'only': 3,
#          '5': 3,
#          'lunch': 3,
#          'sunday': 3,
#          'included': 3,
#          'that': 3,
#          'nutrition': 3,
#          'develop': 3,
#          'arrange': 3,
#          'draft': 3,
#          'prepare': 3,
#          'list': 3,
#          'should': 3,
#          'good': 3,
#          'some': 3,
#          'keto': 2,
#          'low-carb': 2,
#          'work': 2,
#          'two': 2,
#          'breakfast,': 2,
#          'lunch,': 2,
#          'person': 2,
#          'ten': 2,
#          'evenings': 2,
#          'eight': 2,
#          'workweek': 2,
#          'without': 2,
#          'recipes': 2,
#          'portion': 2,
#          'vegetarian': 2,
#          'single': 2,
#          'this': 2,
#          'people': 2,
#          'just': 2,
#          '5-day': 2,
#          'each': 2,
#          'covering': 2,
#          'write': 2,
#          'saturday': 2,
#          'full': 2,
#          'like': 2,
#          'main': 2,
#          'consecutive': 2,
#          'alternating': 2,
#          'iâ\x80\x99m': 2,
#          'cook': 2,
#          'high': 2,
#          'find': 2,
#          'trip.': 2,
#          'diet': 1,
#          'gluten-free': 1,
#          'high-protein': 1,
#          'adults': 1,
#          'an': 1,
#          'entire': 1,
#          'weekdays,': 1,
#          'quick': 1,
#          'desserts': 1,
#          'control': 1,
#          'emphasizing': 1,
#          '2-day': 1,
#          'plan?': 1,
#          'ahead': 1,
#          'getaway': 1,
#          'couple': 1,
#          '1': 1,
#          'trip': 1,
#          'get': 1,
#          'weekend?': 1,
#          'planned': 1,
#          '3-day': 1,
#          '7-day': 1,
#          'me?': 1,
#          'request': 1,
#          '3-meal-a-day': 1,
#          'one-day': 1,
#          'plan,': 1,
#          '4': 1,
#          'covers': 1,
#          'planning,': 1,
#          'please': 1,
#          'iâ\x80\x99d': 1,
#          'straight': 1,
#          'needed': 1,
#          'dayâ\x80\x99s': 1,
#          'weekend-only': 1,
#          'want': 1,
#          '3-meal': 1,
#          'detailed': 1,
#          'breakfasts,': 1,
#          'lunches,': 1,
#          'school': 1,
#          'over': 1,
#          'nine': 1,
#          'budget-friendly': 1,
#          'workdays': 1,
#          'light': 1,
#          'easy': 1,
#          'preparation': 1,
#          'cuisines': 1,
#          'focus': 1,
#          'simplicity': 1,
#          'family-friendly': 1,
#          'treats': 1,
#          'sizes': 1,
#          'far': 1,
#          'it': 1,
#          'from': 1,
#          'boise': 1,
#          'atlanta': 1,
#          'study': 1,
#          'finals': 1,
#          'week.': 1,
#          'quiz': 1,
#          'world': 1,
#          'history': 1,
#          'explain': 1,
#          'neural': 1,
#          'network': 1,
#          'works': 1,
#          '10.': 1,
#          'python': 1,
#          'script': 1,
#          'rename': 1,
#          'files': 1,
#          'folder.': 1,
#          'compare': 1,
#          'relational': 1,
#          'vs': 1,
#          'non-relational': 1,
#          'databases.': 1,
#          'deploy': 1,
#          'website': 1,
#          'using': 1,
#          'github': 1,
#          'pages?': 1,
#          'html': 1,
#          'page': 1,
#          'contact': 1,
#          'form.': 1,
#          "what's": 1,
#          'fastest': 1,
#          'way': 1,
#          'lose': 1,
#          'weight?': 1,
#          'many': 1,
#          'calories': 1,
#          'banana?': 1,
#          'snacks.': 1,
#          'tonight?': 1,
#          'restaurant': 1,
#          'near': 1,
#          'me.': 1,
#          'intermittent': 1,
#          'fasting': 1,
#          'healthy?': 1,
#          'whatâ\x80\x99s': 1,
#          'your': 1,
#          'favorite': 1,
#          'food?': 1,
#          'tell': 1,
#          'funny': 1,
#          'fact.': 1,
#          'quinoa?': 1,
#          'recipe': 1,
#          'chicken': 1,
#          'tikka': 1,
#          'masala.': 1,
#          'prep': 1,
#          'effectively?': 1,
#          'have': 1,
#          'vegan': 1,
#          'recipes?': 1,
#          'desserts.': 1,
#          'ideas?': 1,
#          'smoothie': 1,
#          'recipe.': 1,
#          'much': 1,
#          'protein': 1,
#          'tofu?': 1,
#          'foods': 1,
#          'iron.': 1,
#          'blog.': 1,
#          'gluten': 1,
#          'intolerance?': 1,
#          'eggs': 1,
#          'every': 1,
#          'day?': 1,
#          'sourdough': 1,
#          'starter?': 1,
#          'mediterranean': 1,
#          'diet?': 1,
#          'grocery': 1,
#          'people.': 1,
#          'cookbook?': 1,
#          'avoid': 1,
#          'eating': 1,
#          'cholesterol?': 1,
#          'youtube': 1,
#          'channel': 1,
#          'about': 1,
#          'cooking.': 1,
#          'diabetes.': 1,
#          'before': 1,
#          'workout?': 1,
#          'toddler.': 1,
#          'whoâ\x80\x99s': 1,
#          'lactose': 1,
#          'intolerant.': 1,
#          'camping': 1,
#          'picky': 1,
#          'eaters.': 1,
#          'best': 1,
#          'during': 1,
#          'pregnancy?': 1,
#          'under': 1,
#          '500': 1,
#          'calories.': 1,
#          'if': 1,
#          'budget?': 1,
#          'whole': 1,
#          'family?': 1,
#          'road': 1,
#          "don't": 1,
#          'require': 1,
#          'refrigeration.': 1,
#          'microwave?': 1,
#          'more': 1,
#          'vegetables.': 1,
#          'freeze': 1,
#          'well': 1,
#          'later?': 1,
#          'helps': 1,
#          'energy': 1,
#          'levels.': 1})

# %% [markdown]
# ### Maximum Likelihood

# %%
words_valid_invalid = {}

for col_name in list(set(data.type)):
    sub_df = train[train.type == col_name] #masking data type to only be ham sub-datatype
    words_valid_invalid[col_name] = []
    for row in sub_df.clean:
        for word in row:
            words_valid_invalid[col_name].append(word)
    words_valid_invalid[col_name] = ctr(words_valid_invalid[col_name])

def Pba(W='', X=''):
    t = words_valid_invalid[X]
    if W not in t: return 0.0000001
    return t[W] / sum(t.values())


words_valid_invalid['Valid']
# Out:
# Counter({'for': 140,
#          'plan': 125,
#          'a': 124,
#          'meal': 113,
#          'the': 76,
#          'next': 57,
#          'meals': 39,
#          'days': 31,
#          'week': 23,
#          'me': 19,
#          'with': 19,
#          'days,': 19,
#          'generate': 16,
#          'create': 15,
#          'and': 13,
#          'five': 13,
#          'seven': 12,
#          'including': 12,
#          'give': 11,
#          'weekend': 11,
#          'three': 11,
#          'suggest': 10,
#          'four': 10,
#          'on': 10,
#          '7': 9,
#          'focusing': 9,
#          'dinners': 8,
#          'day': 7,
#          'schedule': 7,
#          'one': 7,
#          'week,': 7,
#          'six': 7,
#          'design': 6,
#          'family': 6,
#          'provide': 6,
#          'breakfasts': 6,
#          '3': 5,
#          'balanced': 5,
#          'healthy': 5,
#          'monday': 5,
#          'snacks': 5,
#          'organize': 5,
#          'make': 5,
#          'i': 5,
#          'all': 5,
#          'lunches': 5,
#          'upcoming': 4,
#          'daily': 4,
#          'friday': 4,
#          'dinner': 4,
#          'help': 4,
#          'outline': 4,
#          'my': 4,
#          'need': 4,
#          'options': 4,
#          'build': 4,
#          'set': 4,
#          'up': 4,
#          '2': 3,
#          'per': 3,
#          'through': 3,
#          'out': 3,
#          'of': 3,
#          'breakfast': 3,
#          'busy': 3,
#          'weekly': 3,
#          'variety': 3,
#          'weekdays': 3,
#          'to': 3,
#          'can': 3,
#          'lunch': 3,
#          'sunday': 3,
#          'included': 3,
#          'nutrition': 3,
#          'develop': 3,
#          'arrange': 3,
#          'draft': 3,
#          'prepare': 3,
#          'keto': 2,
#          'work': 2,
#          'two': 2,
#          'breakfast,': 2,
#          'lunch,': 2,
#          'simple': 2,
#          'person': 2,
#          'ten': 2,
#          'ideas': 2,
#          'evenings': 2,
#          'eight': 2,
#          'workweek': 2,
#          'without': 2,
#          'recipes': 2,
#          'portion': 2,
#          'only': 2,
#          'vegetarian': 2,
#          '5': 2,
#          'single': 2,
#          'this': 2,
#          'you': 2,
#          'people': 2,
#          'just': 2,
#          '5-day': 2,
#          'each': 2,
#          'covering': 2,
#          'show': 2,
#          'saturday': 2,
#          'full': 2,
#          'main': 2,
#          'consecutive': 2,
#          'alternating': 2,
#          'diet': 1,
#          'gluten-free': 1,
#          'high-protein': 1,
#          'low-carb': 1,
#          'adults': 1,
#          'an': 1,
#          'entire': 1,
#          'weekdays,': 1,
#          'quick': 1,
#          'someone': 1,
#          'desserts': 1,
#          'control': 1,
#          'emphasizing': 1,
#          '2-day': 1,
#          'plan?': 1,
#          'ahead': 1,
#          'getaway': 1,
#          'couple': 1,
#          'write': 1,
#          '1': 1,
#          'trip': 1,
#          'get': 1,
#          'weekend?': 1,
#          'planned': 1,
#          '3-day': 1,
#          '7-day': 1,
#          'me?': 1,
#          'request': 1,
#          '3-meal-a-day': 1,
#          'one-day': 1,
#          'plan,': 1,
#          '4': 1,
#          'that': 1,
#          'covers': 1,
#          'planning,': 1,
#          'please': 1,
#          'iâ\x80\x99d': 1,
#          'like': 1,
#          'straight': 1,
#          'needed': 1,
#          'dayâ\x80\x99s': 1,
#          'weekend-only': 1,
#          'want': 1,
#          '3-meal': 1,
#          'detailed': 1,
#          'breakfasts,': 1,
#          'lunches,': 1,
#          'school': 1,
#          'over': 1,
#          'nine': 1,
#          'budget-friendly': 1,
#          'workdays': 1,
#          'light': 1,
#          'easy': 1,
#          'preparation': 1,
#          'cuisines': 1,
#          'focus': 1,
#          'simplicity': 1,
#          'family-friendly': 1,
#          'treats': 1,
#          'sizes': 1})

# %%
Pba(W='the', X='Valid')
# Out:
# 0.058596761757902856

# %%
def Pab(X='', W=''):
    return Pba(W, X) * Pa(X) / Pb(W)

# %%
Pab(X='Valid', W='the')
# Out:
# 0.8786896388997809

# %%
def Ps(T, X=''):
    return np.prod([Pab(X=X, W=word) for word in T])

# %%
Ps(['make', 'meal', 'plan', 'for', 'week'], 'Valid')
# Out:
# np.float64(0.41125812797763356)

# %% [markdown]
# ### Evaluate

# %%
test['Valid'] = test.clean.apply(lambda x: Ps(x, 'Valid'))
test['Invalid'] = test.clean.apply(lambda x: Ps(x, 'Invalid'))

# %%
test['winner'] = test.Valid /  test.Invalid
test['winner'] = test.winner.apply(lambda x: 'Valid' if x>1 else 'Invalid')

# %%
result = test.winner == test.type

# %%
sum(result) / len(test)
# Out:
# 0.9523809523809523

# %%
test
# Out:
#         type                                               text  \
# 25     Valid  Provide a week-long menu with three meals per day
# 165  Invalid            What's a good diet for building muscle?
# 24     Valid  Outline a meal plan for the next five lunches ...
# 207  Invalid     What can I make for a romantic dinner at home?
# 177  Invalid                             What is the DASH diet?
# 197  Invalid            Suggest meals using only 5 ingredients.
# 97     Valid         Generate a meal plan for the next six days
# 5      Valid            Plan 3 meals per day for the next month
# 200  Invalid                  Give me ideas for packed lunches.
# 139    Valid  Provide a meal plan for the next week, with da...
# 13     Valid                Create a vegan meal plan for 7 days
# 206  Invalid                     Recommend comfort food dishes.
# 163  Invalid              Can you make a grocery list for keto?
# 184  Invalid               What are some romantic dinner ideas?
# 117    Valid  Develop a meal plan for a couple for the next ...
# 95     Valid  Outline a meal plan for four days, covering br...
# 105    Valid         Prepare a meal plan for the next two weeks
# 150  Invalid    Explain the concept of entropy in simple terms.
# 7      Valid           Create a vegetarian meal plan for a week
# 6      Valid           Generate a 3 meal plan for 7 days a week
# 132    Valid  Arrange a meal plan for the next week, focusin...
#
#                                                  clean         Valid  \
# 25   [provide, a, week-long, menu, with, three, mea...  1.512921e-03
# 165    [what's, a, good, diet, for, building, muscle?]  1.486450e-11
# 24   [outline, a, meal, plan, for, the, next, five,...  2.712860e-01
# 207  [what, can, i, make, for, a, romantic, dinner,...  1.559480e-10
# 177                       [what, is, the, dash, diet?]  1.945892e-15
# 197     [suggest, meals, using, only, 5, ingredients.]  1.424488e-06
# 97   [generate, a, meal, plan, for, the, next, six,...  3.251842e-01
# 5    [plan, 3, meals, per, day, for, the, next, month]  2.482847e-02
# 200           [give, me, ideas, for, packed, lunches.]  1.317019e-03
# 139  [provide, a, meal, plan, for, the, next, week,...  1.559633e-02
# 13        [create, a, vegan, meal, plan, for, 7, days]  4.235222e-05
# 206                [recommend, comfort, food, dishes.]  3.766222e-12
# 163     [can, you, make, a, grocery, list, for, keto?]  2.590805e-11
# 184        [what, are, some, romantic, dinner, ideas?]  7.987299e-20
# 117  [develop, a, meal, plan, for, a, couple, for, ...  2.107736e-01
# 95   [outline, a, meal, plan, for, four, days,, cov...  2.060535e-01
# 105  [prepare, a, meal, plan, for, the, next, two, ...  2.608311e-02
# 150  [explain, the, concept, of, entropy, in, simpl...  5.056597e-13
# 7    [create, a, vegetarian, meal, plan, for, a, week]  2.754486e-01
# 6    [generate, a, 3, meal, plan, for, 7, days, a, ...  2.604331e-01
# 132  [arrange, a, meal, plan, for, the, next, week,...  1.643477e-01
#
#           Invalid   winner
# 25   2.957234e-26    Valid
# 165  1.272322e-09  Invalid
# 24   6.231005e-40    Valid
# 207  4.224595e-08  Invalid
# 177  3.383579e-03  Invalid
# 197  9.099358e-04  Invalid
# 97   2.596021e-30    Valid
# 5    2.526020e-28    Valid
# 200  3.100260e-06    Valid
# 139  4.785616e-33    Valid
# 13   4.123416e-18    Valid
# 206  1.305070e-03  Invalid
# 163  2.215948e-04  Invalid
# 184  2.407690e-02  Invalid
# 117  2.945533e-30    Valid
# 95   2.766731e-42    Valid
# 105  9.290234e-25    Valid
# 150  2.723581e-07  Invalid
# 7    3.913037e-18    Valid
# 6    1.782771e-34    Valid
# 132  1.280248e-34    Valid
