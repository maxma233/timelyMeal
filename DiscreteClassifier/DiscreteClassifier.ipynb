# %%
import pandas as pd
import numpy as np
from collections import Counter as ctr

# %%
data = pd.read_csv('timelymealsdiscreteannotated.csv', skiprows=1, names=['type','text', 'c3', 'c4', 'c5'], delimiter=',', encoding='ISO-8859-1')

# %%
data['clean'] = data.text.apply(lambda x: x.lower().split())

# %%
data.drop(['c3', 'c4', 'c5'], axis=1, inplace=True)

# %%
data
# Out:
#         type                                               text  \
# 0      Valid                 Generate me a meal plan for 3 days
# 1      Valid  Give me a meal plan for a week and 2 meals per...
# 2      Valid                            Meal plan for the week
# 3      Valid                    Give me a meal plan for the day
# 4      Valid            Generate me a meal plan for the weekend
# ..       ...                                                ...
# 203  Invalid                       Help me eat more vegetables.
# 204  Invalid                  What meals freeze well for later?
# 205  Invalid        Suggest food that helps with energy levels.
# 206  Invalid                     Recommend comfort food dishes.
# 207  Invalid     What can I make for a romantic dinner at home?
#
#                                                  clean
# 0          [generate, me, a, meal, plan, for, 3, days]
# 1    [give, me, a, meal, plan, for, a, week, and, 2...
# 2                         [meal, plan, for, the, week]
# 3             [give, me, a, meal, plan, for, the, day]
# 4     [generate, me, a, meal, plan, for, the, weekend]
# ..                                                 ...
# 203                 [help, me, eat, more, vegetables.]
# 204           [what, meals, freeze, well, for, later?]
# 205  [suggest, food, that, helps, with, energy, lev...
# 206                [recommend, comfort, food, dishes.]
# 207  [what, can, i, make, for, a, romantic, dinner,...
#
# [208 rows x 3 columns]

# %%
data.groupby('type').count()
# Out:
#          text  clean
# type
# Invalid    59     59
# Valid     149    149

# %%
type_ctr = ctr(data.type)

type_ctr['Invalid']/len(data), type_ctr['Valid']/len(data)
# Out:
# (0.28365384615384615, 0.7163461538461539)

# %%
test = data.sample(frac=0.1)
train = data[~data.index.isin(test.index)]

train.shape, test.shape
# Out:
# ((187, 3), (21, 3))

# %% [markdown]
# ### Prior probability

# %%
ham_spam_ctr = ctr(train.type)

def Pa(X=''):
    return ham_spam_ctr[X] / len(train)

# %%
Pa('Valid')
# Out:
# 0.7058823529411765

# %% [markdown]
# ### Normalization

# %%
words_ctr = ctr([word for row in train.clean for word in row])

def Pb(W=''):
    if W not in words_ctr: return 0.000001
    return words_ctr[W] / sum(words_ctr.values())


words_ctr
# Out:
# Counter({'for': 149,
#          'a': 145,
#          'plan': 121,
#          'meal': 111,
#          'the': 77,
#          'next': 54,
#          'meals': 47,
#          'days': 29,
#          'me': 25,
#          'week': 24,
#          'with': 24,
#          'days,': 19,
#          'generate': 17,
#          'create': 17,
#          'suggest': 15,
#          'i': 15,
#          'what': 13,
#          'give': 12,
#          'and': 12,
#          'seven': 12,
#          'on': 12,
#          'five': 11,
#          'including': 11,
#          'weekend': 10,
#          'three': 10,
#          '7': 9,
#          'focusing': 9,
#          'four': 9,
#          'make': 9,
#          'can': 9,
#          'day': 8,
#          'week,': 8,
#          'provide': 8,
#          'how': 8,
#          'schedule': 7,
#          'one': 7,
#          'dinners': 7,
#          '3': 6,
#          'healthy': 6,
#          'design': 6,
#          'dinner': 6,
#          'outline': 6,
#          'lunches': 6,
#          'to': 6,
#          'all': 6,
#          'six': 6,
#          'is': 6,
#          'balanced': 5,
#          'daily': 5,
#          'monday': 5,
#          'snacks': 5,
#          'family': 5,
#          'you': 5,
#          'show': 5,
#          'in': 5,
#          'do': 5,
#          'food': 5,
#          'per': 4,
#          'upcoming': 4,
#          'friday': 4,
#          'help': 4,
#          'organize': 4,
#          'breakfast': 4,
#          'ideas': 4,
#          'only': 4,
#          'my': 4,
#          'of': 4,
#          'options': 4,
#          'develop': 4,
#          'are': 4,
#          'list': 4,
#          'recommend': 4,
#          'good': 4,
#          'some': 4,
#          'eat': 4,
#          '2': 3,
#          'through': 3,
#          'two': 3,
#          'simple': 3,
#          'out': 3,
#          'someone': 3,
#          'busy': 3,
#          'weekly': 3,
#          'weekdays': 3,
#          'need': 3,
#          'covering': 3,
#          'sunday': 3,
#          'included': 3,
#          'that': 3,
#          '5': 3,
#          'nutrition': 3,
#          'set': 3,
#          'up': 3,
#          'prepare': 3,
#          'draft': 3,
#          'arrange': 3,
#          'should': 3,
#          'vegetarian': 2,
#          'keto': 2,
#          'diet': 2,
#          'low-carb': 2,
#          'vegan': 2,
#          'work': 2,
#          'breakfast,': 2,
#          'lunch,': 2,
#          'person': 2,
#          'ten': 2,
#          'quick': 2,
#          'evenings': 2,
#          'workweek': 2,
#          'without': 2,
#          'recipes': 2,
#          'portion': 2,
#          'variety': 2,
#          'single': 2,
#          'this': 2,
#          'people': 2,
#          'just': 2,
#          'each': 2,
#          'write': 2,
#          'saturday': 2,
#          'full': 2,
#          'lunch': 2,
#          'like': 2,
#          'main': 2,
#          'build': 2,
#          'alternating': 2,
#          'breakfasts': 2,
#          'explain': 2,
#          'iâ\x80\x99m': 2,
#          'using': 2,
#          "what's": 2,
#          'cook': 2,
#          'grocery': 2,
#          'ideas?': 2,
#          'high': 2,
#          'diet?': 2,
#          'romantic': 2,
#          'trip.': 2,
#          'gluten-free': 1,
#          'adults': 1,
#          'an': 1,
#          'entire': 1,
#          'week-long': 1,
#          'menu': 1,
#          'weekdays,': 1,
#          'desserts': 1,
#          'control': 1,
#          'emphasizing': 1,
#          '2-day': 1,
#          'plan?': 1,
#          'ahead': 1,
#          'getaway': 1,
#          '1': 1,
#          'trip': 1,
#          'get': 1,
#          'weekend?': 1,
#          '3-day': 1,
#          '7-day': 1,
#          'me?': 1,
#          'request': 1,
#          '3-meal-a-day': 1,
#          '5-day': 1,
#          'one-day': 1,
#          'plan,': 1,
#          '4': 1,
#          'covers': 1,
#          'planning,': 1,
#          'please': 1,
#          'iâ\x80\x99d': 1,
#          'straight': 1,
#          'needed': 1,
#          'dayâ\x80\x99s': 1,
#          'weekend-only': 1,
#          'want': 1,
#          '3-meal': 1,
#          'detailed': 1,
#          'consecutive': 1,
#          'breakfasts,': 1,
#          'lunches,': 1,
#          'school': 1,
#          'weeks': 1,
#          'over': 1,
#          'nine': 1,
#          'budget-friendly': 1,
#          'workdays': 1,
#          'eight': 1,
#          'couple': 1,
#          'light': 1,
#          'easy': 1,
#          'preparation': 1,
#          'cuisines': 1,
#          'focus': 1,
#          'simplicity': 1,
#          'suggestions': 1,
#          'family-friendly': 1,
#          'sizes': 1,
#          'far': 1,
#          'it': 1,
#          'from': 1,
#          'boise': 1,
#          'atlanta': 1,
#          'concept': 1,
#          'entropy': 1,
#          'terms.': 1,
#          'study': 1,
#          'finals': 1,
#          'week.': 1,
#          'quiz': 1,
#          'world': 1,
#          'history': 1,
#          'neural': 1,
#          'network': 1,
#          'works': 1,
#          '10.': 1,
#          'python': 1,
#          'script': 1,
#          'rename': 1,
#          'files': 1,
#          'folder.': 1,
#          'compare': 1,
#          'relational': 1,
#          'vs': 1,
#          'non-relational': 1,
#          'databases.': 1,
#          'deploy': 1,
#          'website': 1,
#          'github': 1,
#          'pages?': 1,
#          'fastest': 1,
#          'way': 1,
#          'lose': 1,
#          'weight?': 1,
#          'many': 1,
#          'calories': 1,
#          'banana?': 1,
#          'snacks.': 1,
#          'tonight?': 1,
#          'restaurant': 1,
#          'near': 1,
#          'me.': 1,
#          'keto?': 1,
#          'intermittent': 1,
#          'fasting': 1,
#          'healthy?': 1,
#          'building': 1,
#          'muscle?': 1,
#          'whatâ\x80\x99s': 1,
#          'your': 1,
#          'favorite': 1,
#          'food?': 1,
#          'tell': 1,
#          'funny': 1,
#          'fact.': 1,
#          'quinoa?': 1,
#          'recipe': 1,
#          'chicken': 1,
#          'tikka': 1,
#          'masala.': 1,
#          'prep': 1,
#          'effectively?': 1,
#          'have': 1,
#          'recipes?': 1,
#          'desserts.': 1,
#          'smoothie': 1,
#          'recipe.': 1,
#          'much': 1,
#          'protein': 1,
#          'tofu?': 1,
#          'foods': 1,
#          'iron.': 1,
#          'dash': 1,
#          'gluten': 1,
#          'intolerance?': 1,
#          'eggs': 1,
#          'every': 1,
#          'day?': 1,
#          'sourdough': 1,
#          'starter?': 1,
#          'mediterranean': 1,
#          'people.': 1,
#          'cookbook?': 1,
#          'avoid': 1,
#          'eating': 1,
#          'cholesterol?': 1,
#          'find': 1,
#          'youtube': 1,
#          'channel': 1,
#          'about': 1,
#          'cooking.': 1,
#          'diabetes.': 1,
#          'before': 1,
#          'workout?': 1,
#          'whoâ\x80\x99s': 1,
#          'lactose': 1,
#          'intolerant.': 1,
#          'camping': 1,
#          'picky': 1,
#          'eaters.': 1,
#          'under': 1,
#          '500': 1,
#          'calories.': 1,
#          'if': 1,
#          'budget?': 1,
#          'ingredients.': 1,
#          'whole': 1,
#          'family?': 1,
#          'road': 1,
#          'packed': 1,
#          'lunches.': 1,
#          "don't": 1,
#          'require': 1,
#          'refrigeration.': 1,
#          'microwave?': 1,
#          'more': 1,
#          'vegetables.': 1,
#          'freeze': 1,
#          'well': 1,
#          'later?': 1,
#          'helps': 1,
#          'energy': 1,
#          'levels.': 1,
#          'comfort': 1,
#          'dishes.': 1,
#          'at': 1,
#          'home?': 1})

# %% [markdown]
# ### Maximum Likelihood

# %%
words_ham_spam = {}

for col_name in list(set(data.type)):
    sub_df = train[train.type == col_name] #masking data type to only be ham sub-datatype
    words_ham_spam[col_name] = []
    for row in sub_df.clean:
        for word in row:
            words_ham_spam[col_name].append(word)
    words_ham_spam[col_name] = ctr(words_ham_spam[col_name])

def Pba(W='', X=''):
    t = words_ham_spam[X]
    if W not in t: return 0.0000001
    return t[W] / sum(t.values())


words_ham_spam['Valid']
# Out:
# Counter({'for': 134,
#          'a': 123,
#          'plan': 120,
#          'meal': 110,
#          'the': 72,
#          'next': 54,
#          'meals': 38,
#          'days': 29,
#          'week': 24,
#          'with': 20,
#          'days,': 19,
#          'generate': 17,
#          'me': 16,
#          'create': 15,
#          'and': 12,
#          'seven': 12,
#          'five': 11,
#          'including': 11,
#          'weekend': 10,
#          'three': 10,
#          'on': 10,
#          'give': 9,
#          '7': 9,
#          'suggest': 9,
#          'focusing': 9,
#          'four': 9,
#          'day': 8,
#          'week,': 8,
#          'provide': 8,
#          'one': 7,
#          'dinners': 7,
#          '3': 6,
#          'schedule': 6,
#          'design': 6,
#          'outline': 6,
#          'lunches': 6,
#          'six': 6,
#          'balanced': 5,
#          'daily': 5,
#          'healthy': 5,
#          'monday': 5,
#          'snacks': 5,
#          'family': 5,
#          'make': 5,
#          'all': 5,
#          'per': 4,
#          'upcoming': 4,
#          'friday': 4,
#          'organize': 4,
#          'my': 4,
#          'i': 4,
#          'options': 4,
#          'develop': 4,
#          '2': 3,
#          'through': 3,
#          'two': 3,
#          'dinner': 3,
#          'out': 3,
#          'help': 3,
#          'breakfast': 3,
#          'busy': 3,
#          'weekly': 3,
#          'weekdays': 3,
#          'need': 3,
#          'to': 3,
#          'can': 3,
#          'covering': 3,
#          'sunday': 3,
#          'included': 3,
#          'nutrition': 3,
#          'set': 3,
#          'up': 3,
#          'prepare': 3,
#          'draft': 3,
#          'arrange': 3,
#          'vegetarian': 2,
#          'keto': 2,
#          'work': 2,
#          'breakfast,': 2,
#          'lunch,': 2,
#          'simple': 2,
#          'person': 2,
#          'ten': 2,
#          'quick': 2,
#          'ideas': 2,
#          'evenings': 2,
#          'workweek': 2,
#          'without': 2,
#          'recipes': 2,
#          'portion': 2,
#          'variety': 2,
#          'only': 2,
#          'single': 2,
#          'this': 2,
#          'of': 2,
#          'you': 2,
#          'people': 2,
#          'just': 2,
#          'each': 2,
#          'show': 2,
#          'saturday': 2,
#          'full': 2,
#          'lunch': 2,
#          'main': 2,
#          'build': 2,
#          'alternating': 2,
#          'breakfasts': 2,
#          'diet': 1,
#          'gluten-free': 1,
#          'low-carb': 1,
#          'vegan': 1,
#          'adults': 1,
#          'an': 1,
#          'entire': 1,
#          'week-long': 1,
#          'menu': 1,
#          'weekdays,': 1,
#          'someone': 1,
#          'desserts': 1,
#          'control': 1,
#          'emphasizing': 1,
#          '2-day': 1,
#          'plan?': 1,
#          'ahead': 1,
#          'getaway': 1,
#          'write': 1,
#          '1': 1,
#          'trip': 1,
#          'get': 1,
#          'weekend?': 1,
#          '3-day': 1,
#          '7-day': 1,
#          'me?': 1,
#          'request': 1,
#          '3-meal-a-day': 1,
#          '5-day': 1,
#          'one-day': 1,
#          'plan,': 1,
#          '4': 1,
#          'that': 1,
#          'covers': 1,
#          'planning,': 1,
#          'please': 1,
#          'iâ\x80\x99d': 1,
#          'like': 1,
#          'straight': 1,
#          'needed': 1,
#          'dayâ\x80\x99s': 1,
#          'weekend-only': 1,
#          '5': 1,
#          'want': 1,
#          '3-meal': 1,
#          'detailed': 1,
#          'consecutive': 1,
#          'breakfasts,': 1,
#          'lunches,': 1,
#          'school': 1,
#          'weeks': 1,
#          'over': 1,
#          'nine': 1,
#          'budget-friendly': 1,
#          'workdays': 1,
#          'eight': 1,
#          'couple': 1,
#          'light': 1,
#          'easy': 1,
#          'preparation': 1,
#          'cuisines': 1,
#          'focus': 1,
#          'simplicity': 1,
#          'suggestions': 1,
#          'family-friendly': 1,
#          'sizes': 1})

# %%
Pba(W='the', X='Valid')
# Out:
# 0.05741626794258373

# %%
def Pab(X='', W=''):
    return Pba(W, X) * Pa(X) / Pb(W)

# %%
Pab(X='Valid', W='the')
# Out:
# 0.8469009178268959

# %%
def Ps(T, X=''):
    return np.prod([Pab(X=X, W=word) for word in T])

# %%
Ps(['make', 'meal', 'plan', 'for', 'week'], 'Valid')
# Out:
# np.float64(0.29927178109619446)

# %% [markdown]
# ### Evaluate

# %%
test['Valid'] = test.clean.apply(lambda x: Ps(x, 'Valid'))
test['Invalid'] = test.clean.apply(lambda x: Ps(x, 'Invalid'))

# %%
test['winner'] = test.Valid /  test.Invalid
test['winner'] = test.winner.apply(lambda x: 'Valid' if x>1 else 'Invalid')

# %%
result = test.winner == test.type

# %%
sum(result) / len(test)
# Out:
# 0.9523809523809523

# %%
test
# Out:
#         type                                               text  \
# 133    Valid   Prepare a meal plan for the next four breakfasts
# 142    Valid  Organize a meal plan for the next five days, f...
# 43     Valid          Give me a vegetarian meal plan for 5 days
# 66     Valid       I need meals planned for the next three days
# 120    Valid  Schedule a meal plan for the next three breakf...
# 33     Valid  Create a meal plan for the next week with brea...
# 11     Valid       Generate a high-protein meal plan for 7 days
# 178  Invalid                               Find me a food blog.
# 115    Valid  Build a meal plan for five consecutive breakfasts
# 68     Valid                    Help me plan meals for the week
# 143    Valid  Build a meal plan for the next week, including...
# 104    Valid  Arrange a meal plan for the next five breakfas...
# 194  Invalid              What meals are best during pregnancy?
# 23     Valid  Suggest a meal plan for a family of four for s...
# 5      Valid            Plan 3 meals per day for the next month
# 190  Invalid                     Recommend meals for a toddler.
# 62     Valid                  Meal plan for a couple for 7 days
# 55     Valid          Create a 5-day lunch and dinner meal plan
# 144    Valid        Set up a meal plan for the next six dinners
# 30     Valid       Give me a meal plan for the next eight meals
# 157  Invalid      Build a simple HTML page with a contact form.
#
#                                                  clean         Valid  \
# 133  [prepare, a, meal, plan, for, the, next, four,...  2.875282e-01
# 142  [organize, a, meal, plan, for, the, next, five...  1.780212e-01
# 43   [give, me, a, vegetarian, meal, plan, for, 5, ...  4.919927e-02
# 66   [i, need, meals, planned, for, the, next, thre...  5.795271e-03
# 120  [schedule, a, meal, plan, for, the, next, thre...  2.464528e-01
# 33   [create, a, meal, plan, for, the, next, week, ...  7.113362e-02
# 11   [generate, a, high-protein, meal, plan, for, 7...  2.645997e-02
# 178                         [find, me, a, food, blog.]  8.110317e-11
# 115  [build, a, meal, plan, for, five, consecutive,...  3.395063e-01
# 68             [help, me, plan, meals, for, the, week]  1.618151e-01
# 143  [build, a, meal, plan, for, the, next, week,, ...  1.838246e-02
# 104  [arrange, a, meal, plan, for, the, next, five,...  2.358643e-01
# 194       [what, meals, are, best, during, pregnancy?]  6.389207e-14
# 23   [suggest, a, meal, plan, for, a, family, of, f...  5.228632e-02
# 5    [plan, 3, meals, per, day, for, the, next, month]  2.155266e-02
# 190               [recommend, meals, for, a, toddler.]  9.184903e-07
# 62          [meal, plan, for, a, couple, for, 7, days]  3.053278e-01
# 55   [create, a, 5-day, lunch, and, dinner, meal, p...  1.665489e-01
# 144  [set, up, a, meal, plan, for, the, next, six, ...  2.604182e-01
# 30   [give, me, a, meal, plan, for, the, next, eigh...  1.010644e-01
# 157  [build, a, simple, html, page, with, a, contac...  6.049022e-06
#
#           Invalid   winner
# 133  5.346819e-28    Valid
# 142  9.546896e-40    Valid
# 43   1.970926e-17    Valid
# 66   9.102109e-27    Valid
# 120  5.809421e-24    Valid
# 33   2.754609e-35    Valid
# 11   2.522955e-24    Valid
# 178  5.073099e-03  Invalid
# 115  4.093570e-25    Valid
# 68   1.030255e-11    Valid
# 143  2.283362e-35    Valid
# 104  1.166327e-38    Valid
# 194  1.154129e-05  Invalid
# 23   2.219105e-29    Valid
# 5    4.648076e-28    Valid
# 190  2.716567e-04  Invalid
# 62   1.957001e-22    Valid
# 55   1.235269e-20    Valid
# 144  3.614719e-33    Valid
# 30   5.263425e-19    Valid
# 157  7.150945e-14    Valid
